# %% [markdown]
# # Kaggle Space — Ambiente Python e Jupyter Notebook
# Este notebook é um ponto de partida para um Kaggle Space com Python.
#
# Abra as células e execute para verificar o ambiente.

# %%
# Importar bibliotecas básicas
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print('Python:', sys.version.split()[0])
print('NumPy:', np.__version__)
print('Pandas:', pd.__version__)
print('
Exemplo simples: criar DataFrame e mostrar as 5 primeiras linhas')
df = pd.DataFrame({'x': np.arange(10), 'y': np.random.randn(10)})
df.head()
